# %% [markdown]
# ![Desktop - 38.png](data:image/png;base64,...)

# %% [markdown]
# 📌 `Natural Language Toolkit (NLTK)` is one of the largest Python libraries for performing various Natural Language Processing tasks. From rudimentary tasks such as text pre-processing to tasks like vectorized representation of text

# %%
#Loading NLTK
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-57945934.py in <cell line: 0>()
#       1 #Loading NLTK
#       2 import nltk
# ----> 3 nltk.download()
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     758             if download_dir is not None:
#     759                 self._download_dir = download_dir
# --> 760             self._interactive_download()
#     761             return True
#     762
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in _interactive_download(self)
#    1110                 DownloaderGUI(self).mainloop()
#    1111             except TclError:
# -> 1112                 DownloaderShell(self).run()
#    1113         else:
#    1114             DownloaderShell(self).run()
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in run(self)
#    1136                 "q) Quit",
#    1137             )
# -> 1138             user_input = input("Downloader> ").strip()
#    1139             if not user_input:
#    1140                 print()
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# 📌 Tokenization refers to break down the text into smaller units. It entails splitting paragraphs into sentences and sentences into words. It is one of the initial steps of any NLP pipeline.
#
# Let us have a look at the two major kinds of tokenization that NLTK provides:

# %% [markdown]
# # Sentence Tokenizing

# %%
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# # Word Tokenizing

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %% [markdown]
# # Stopwords

# %% [markdown]
# 📌 Stop words are common words in a language that are often filtered out during nlp tasks because they carry little meaning or contribute minimally to the overall understanding of a text. Examples include "the," "is," "and," "in," etc.

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'only', 't', "i'll", 'didn', 'having', 'an', 'if', 'now', 'or', "she's", 'that', 'o', "aren't", 'did', "weren't", 'mightn', 'yours', 'do', 'themselves', "i'd", "she'd", 'doing', 'does', 'each', "we've", 'off', 'yourselves', 'those', 'theirs', "they'll", 'his', 'than', "mightn't", 'here', 'there', "that'll", 'and', 'no', 'not', 'further', 'myself', 'own', 'at', 'being', 'while', "i'm", 'shouldn', 'i', 'why', 'up', 'you', "you'd", 'doesn', 'm', 'before', "you're", "haven't", "she'll", 'll', 'will', 'for', 'on', 'until', 'so', 'then', 'were', 'hadn', 'can', 'itself', 'its', 'aren', 'in', 'once', 'nor', "couldn't", 'him', 'their', 'have', 'haven', 'how', 'most', "i've", "hadn't", 'mustn', 'where', 'above', 'under', 'the', 'are', "wasn't", 'had', 'am', 'don', 'is', 'me', 'we', 'they', 'down', 's', 'other', 'because', 'whom', "it'll", 'which', 'against', 'd', 'shan', 'such', 'as', "don't", "wouldn't", 'very', 'who', "we'll", 'all', 'ain', 'ourselves', "it's", 'her', 'our', "isn't", 'your', 'been', 'during', 'it', "he's", "you'll", "hasn't", 've', 'same', 'just', "you've", 're', "shouldn't", 'this', 'he', 'by', "needn't", 'of', "we'd", 'ma', "we're", "mustn't", "didn't", 'to', 'below', 'himself', "he'll", 'through', "won't", 'about', 'herself', "they've", "doesn't", 'y', 'a', 'yourself', 'both', 'has', "they'd", 'wasn', "it'd", "shan't", 'isn', 'when', 'few', 'what', 'them', 'out', 'too', 'couldn', 'more', 'should', "he'd", 'these', 'over', 'hers', 'be', 'after', 'some', "they're", 'between', 'weren', 'from', 'won', 'any', 'ours', 'my', 'hasn', 'into', "should've", 'she', 'was', 'needn', 'wouldn', 'but', 'with', 'again'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Removing Stopwords

# %%
filtered_sent=[]
for w in tokenized_word:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']
# Filterd Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard']

# %% [markdown]
# # Stemming

# %% [markdown]
# 📌 Stemming generates the base word from the inflected word by removing the affixes of the word. It has a set of pre-defined rules that govern the dropping of these affixes.
#
# 📌 It must be noted that stemmers might not always result in semantically meaningful base words.  Stemmers are faster and computationally less expensive than lemmatizers.

# %%
import nltk

# %%
# Stemming
from nltk.stem import   PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard']
# Stemmed Sentence: ['hello', 'mr.', 'smith', ',', 'today', '?', 'the', 'weather', 'great', ',', 'citi', 'awesom', '.', 'the', 'sky', 'pinkish-blu', '.', 'you', "n't", 'eat', 'cardboard']

# %% [markdown]
# # Lemmatization

# %% [markdown]
# 📌 Lemmatization involves grouping together the inflected forms of the same word. This way, we can reach out to the base form of any word which will be meaningful in nature. The base form here is called the Lemma.
#
# 📌 Lemmatizers are slower and computationally more expensive than stemmers.

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import nltk

nltk.download('wordnet')
lem = WordNetLemmatizer()
stem = PorterStemmer()

word = "is"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Lemmatized Word: be
# Stemmed Word: is

# %% [markdown]
# # POS Tagging

# %% [markdown]
# 📌 Part of Speech (POS) tagging refers to assigning each word of a sentence to its part of speech. It is significant as it helps to give a better syntactic overview of a sentence.

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')

nltk.pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]
